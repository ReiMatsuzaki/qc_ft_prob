# %%
# %load_ext autoreload
# %autoreload 2

# %%
from newsvendor import solve_newsvendor_qaoa, comprehensive_analysis

# %%
from scipy.stats import norm
mu, sigma = 3, 1
D_max = 5
Q_max = 5
demand_pdf = lambda x: norm.pdf(x, mu, sigma)
result = solve_newsvendor_qaoa(
    demand_dist=demand_pdf,
    c=1.0,
    lam=5.0,
    Q_max=Q_max,
    D_max=D_max,
    p=1,            # QAOA深さ
    M=4,            # フーリエ打ち切り次数
    n_shots=500,    # 測定回数
    verbose=True
)
# Out:
# ============================================================
# Newsvendor Problem with FSL + QAOA
# ============================================================
# Problem size: Q_max=5, D_max=5
# Qubits: n_q=3, n_d=3, total=10
# QAOA depth: p=1, Fourier truncation: M=4
# Warning: Demand distribution sum is 0.995298, renormalizing.
# Demand distribution encoded with 9 Fourier modes
#
# Optimizing QAOA parameters...
#   Iteration 10: cost = 4.9618
#   Iteration 20: cost = 4.6025
#   Iteration 30: cost = 4.5834
# Optimization completed: 31 function evaluations
#
# ============================================================
# RESULTS
# ============================================================
# Quantum solution: q = 4
# Quantum cost: 4.2712
# Classical solution: q = 4
# Classical cost: 4.2712
# Approximation ratio: 1.0000
# Measurement confidence: 44.05%
# Circuit depth (estimated): 20

# %%
comprehensive_analysis(result)
# Out:
# ======================================================================
# COMPREHENSIVE QAOA ANALYSIS
# ======================================================================
#
# 1. OPTIMIZATION CONVERGENCE ANALYSIS
# ----------------------------------------------------------------------
#
# Convergence plot saved to: qaoa_convergence.png
# 2. CIRCUIT STRUCTURE ANALYSIS
# ----------------------------------------------------------------------
#
# ============================================================
# CIRCUIT STRUCTURE ANALYSIS
# ============================================================
#
# Circuit Statistics:
#   Total qubits: 10
#   Total gates: 64
#   Estimated depth: 20
#   QAOA layers (p): 1
#
# Register Layout:
#   R_q (order quantity): qubits 0-2 (3 qubits)
#   R_d (demand): qubits 3-5 (3 qubits)
#   R_f (stockout flag): qubit 6
#   Ancilla: qubits 7+
#
# Gate Composition:
#   QuantumGateMatrix: 30
#   ClsOneQubitGate: 19
#   ClsOneQubitRotationGate: 7
#   ClsOneControlOneTargetGate: 6
#   ClsTwoQubitGate: 2
#
# 3. FSL ENCODING FIDELITY
# ----------------------------------------------------------------------
#
# ============================================================
# FSL ENCODING FIDELITY ANALYSIS
# ============================================================
#
# FSL Circuit Info:
#   Number of Fourier modes: 9
#   Max mode index (M): 4
#   Number of qubits: 4
#   Dimension: 16
#   Circuit gates: 30 (FSL + IQFT)
#
# Fidelity Metrics:
#   Classical Fidelity: 0.945414 (94.5414%)
#   Target = 1.0 (100%)
#   Total Variation Distance: 0.147159
#   Target = 0.0 (perfect match)
#
# FSL fidelity plot saved to: fsl_fidelity.png
# 4. FINAL RESULTS
# ----------------------------------------------------------------------
#
# Visualization saved to: newsvendor_results.png
# ======================================================================
# ANALYSIS SUMMARY
# ======================================================================
# Quantum Solution: q = 4
# Classical Solution: q = 4
# Approximation Ratio: 1.0000
# FSL Fidelity: 0.945414
# Optimization Iterations: 31
# Best Cost Achieved: 4.5545
# ======================================================================

# %%
mu, sigma = 10, 3
D_max = 31
Q_max = 31
demand_pdf = lambda x: norm.pdf(x, mu, sigma)
result = solve_newsvendor_qaoa(
    demand_dist=demand_pdf,
    c=1.0,
    lam=5.0,
    Q_max=Q_max,
    D_max=D_max,
    p=1,            # QAOA深さ
    M=4,            # フーリエ打ち切り次数
    n_shots=500,    # 測定回数
    verbose=True
)
comprehensive_analysis(result)
